# %% [markdown]
# ### Библиотеки

# %%
from my_package.game import *
from my_package.utils import *

# %% [markdown]
# ### Проведение исследования

# %%
distribution_two_cubics = [
    0.02,
    0.05,
    0.08,
    0.12,
    0.18,
    0.30,
    0.12,
    0.06,
    0.04,
    0.02,
    0.01
]
visul = VisualizationsResultRols(title_figure='Частота попадания на поля Монополии')

logic_cubes = GameCubes(distribution_two_cubics)

result_board = walk(0, 70, logic_cubes)

# %%
print(result_board.places)
visul.create_hist(result_board)
# Out:
# {0: 1, 1: 2, 2: 4, 3: 1, 4: 1, 5: 1, 6: 3, 7: 2, 8: 2, 9: 2, 10: 2, 11: 0, 12: 3, 13: 2, 14: 3, 15: 0, 16: 1, 17: 2, 18: 1, 19: 2, 20: 3, 21: 2, 22: 1, 23: 1, 24: 0, 25: 4, 26: 3, 27: 1, 28: 2, 29: 1, 30: 0, 31: 1, 32: 3, 33: 2, 34: 3, 35: 1, 36: 2, 37: 0, 38: 2, 39: 3}
# d:\Data-sience\ProbabilityTheory\monopoly\my_package\utils\visualization.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(game_board.names_place, rotation=45, ha='right')
# d:\Data-sience\ProbabilityTheory\monopoly\my_package\utils\visualization.py:26: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()
